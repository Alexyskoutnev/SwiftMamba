# %%
import torch 
from PIL import Image

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in /home/alexy/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-4-9 Python-3.10.14 torch-2.2.2 CUDA:0 (NVIDIA GeForce RTX 4090, 24217MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# Adding AutoShape...

# %%
# Load image
image_path = 'car.jpg'
image = Image.open(image_path)

# Perform inference
results = model(image)

# Display results
results.show()

# Save results
results.save('results')
# Out:
# <PIL.Image.Image image mode=RGB size=1024x574>
# Saved 1 image to runs/detect/exp3

# %%
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
#          xmin        ymin         xmax        ymax  confidence  class  \
# 0    0.000000  173.590347   182.062668  280.899719    0.922249      2
# 1  117.078178  133.692337   918.695496  533.829895    0.840909      2
# 2  556.220886  107.443291   951.475586  297.293488    0.821755      2
# 3  989.636047  152.556030  1024.000000  182.703049    0.589192      2
# 4  456.124573  116.704567   647.467041  172.906769    0.501338      2
# 5  334.344940   30.511652   372.431061  139.838501    0.461875     11
# 6  942.116028  148.571091   996.209412  206.388458    0.394682      2
#
#         name
# 0        car
# 1        car
# 2        car
# 3        car
# 4        car
# 5  stop sign
# 6        car
